# %%
% matplotlib inline
% load_ext autoreload
% autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from torch.autograd import backward
from torch.optim import lr_scheduler, RMSprop,Adam
from torch.utils.data import Dataset, DataLoader

from spam_utils import *

# %%
corpus=Corpus()
model=Model(corpus,num_embeddings=None,embedding_dim=50,hidden_size=128,hidden_dim=64).cuda()
optimizer=Adam(model.parameters())
loss_fn=nn.BCELoss().cuda()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-226c1083c47a> in <module>()
# ----> 1 corpus=Corpus()
#       2 model=Model(corpus,num_embeddings=None,embedding_dim=50,hidden_size=128,hidden_dim=64).cuda()
#       3 optimizer=Adam(model.parameters())
#       4 loss_fn=nn.BCELoss().cuda()
#
# ~/PycharmProjects/spam-message-classification/spam_utils.py in __init__(self)
#      28         self.sentence_lengths = []
#      29         data = read_csv('data/train.csv')
# ---> 30         labels = np.array(list(map(lambda x: 0 if x == 'ham' else 1, data[:, 0])))
#      31         sentences = data[:, 1]
#      32         for sentence in sentences:
#
# IndexError: too many indices for array

# %%
dataloaders={'train':DataLoader(SpamSet(True),batch_size=8,shuffle=True),
             'dev':DataLoader(SpamSet(False),batch_size=8,shuffle=False)}

# %%
fit(model, loss_fn, optimizer, dataloaders, {'accuracy': accuracy_score}, num_epochs=10, save=False)
# Out:
# N/A% (0 of 592) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--
#   1% (8 of 592) |                        | Elapsed Time: 0:00:00 ETA:  00:00:00
#   2% (15 of 592) |                       | Elapsed Time: 0:00:00 ETA:   0:00:05
# Starting epoch 1 / 10
# tensor([[2.1798e-11],
#         [1.1674e-08],
#         [2.4597e-08],
#         [3.2356e-08],
#         [1.9685e-08],
#         [1.0441e-10],
#         [7.0179e-08],
#         [1.5113e-12]], device='cuda:0', grad_fn=<SigmoidBackward>) tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:0')
# tensor([[3.0073e-07],
#         [3.1736e-07],
#         [1.0000e+00],
#         [1.6771e-06],
#         [5.2383e-03],
#         [1.9961e-05],
#         [6.8459e-10],
#         [3.9843e-09]], device='cuda:0', grad_fn=<SigmoidBackward>) tensor([[0.],
#         [0.],
#         [1.],
#         [0.],
#         [0.],
#         [0.],
#         [0.],
# ...
